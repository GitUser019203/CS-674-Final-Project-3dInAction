# %% [markdown]
# # Extract 567 Point Cloud Videos

# %%
# !cd '/content/drive/MyDrive/Colab Notebooks/COMPSCI 674/Final Project/MSRAction3DFPS/MSRAction3D_fps' && python create_dataset.py

# %% [markdown]
# # Get Information about Video Actions, Subjects and Retakes

# %%
# !cd '/content/drive/MyDrive/Colab Notebooks/COMPSCI 674/Final Project/MSRAction3DFPS/MSRAction3D_fps' && python get_file_names.py
# Out:
# {'01': 27, '02': 27, '03': 27, '04': 26, '05': 26, '06': 26, '07': 28, '08': 30, '09': 30, '10': 30, '11': 30, '12': 30, '13': 30, '14': 30, '15': 20, '16': 30, '17': 30, '18': 30, '19': 30, '20': 30}
# {'01': 60, '02': 59, '03': 56, '04': 38, '05': 57, '06': 58, '07': 59, '08': 60, '09': 60, '10': 60}
# {'01': 191, '02': 191, '03': 185}
# 567
